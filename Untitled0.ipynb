# %%
import pandas as pd

# %% [markdown]
# Load the pandas libraries with alias 'pd'

# %%
df=pd.read_csv("/100-contacts.csv")

# %% [markdown]
# Read a comma-separated values (csv) file into DataFrame.

# %%
df
# Out:
#    first_name  last_name                    company_name  \
# 0       James       Butt               Benton, John B Jr
# 1   Josephine    Darakjy           Chanay, Jeffrey A Esq
# 2         Art     Venere             Chemel, James L Cpa
# 3       Lenna   Paprocki          Feltz Printing Service
# 4     Donette     Foller             Printing Dimensions
# ..        ...        ...                             ...
# 94     Elvera  Benimadho                 Tree Musketeers
# 95      Carma  Vanheusen    Springfield Div Oh Edison Co
# 96    Malinda    Hochard         Logan Memorial Hospital
# 97    Natalie       Fern            Kelly, Charles G Esq
# 98      Lisha    Centini  Industrial Paper Shredders Inc
#
#                   address          city       county state    zip  \
# 0      6649 N Blue Gum St   New Orleans      Orleans    LA  70116
# 1     4 B Blue Ridge Blvd      Brighton   Livingston    MI  48116
# 2    8 W Cerritos Ave #54    Bridgeport   Gloucester    NJ   8014
# ...

# %% [markdown]
# Print the whole csv file.

# %%
df.set_index("county")
# Out:
#             first_name  last_name                    company_name  \
# county
# Orleans          James       Butt               Benton, John B Jr
# Livingston   Josephine    Darakjy           Chanay, Jeffrey A Esq
# Gloucester         Art     Venere             Chemel, James L Cpa
# Anchorage        Lenna   Paprocki          Feltz Printing Service
# Butler         Donette     Foller             Printing Dimensions
# ...                ...        ...                             ...
# Santa Clara     Elvera  Benimadho                 Tree Musketeers
# Alameda          Carma  Vanheusen    Springfield Div Oh Edison Co
# Marion         Malinda    Hochard         Logan Memorial Hospital
# Sweetwater     Natalie       Fern            Kelly, Charles G Esq
# Fairfax          Lisha    Centini  Industrial Paper Shredders Inc
#
#                            address          city state    zip        phone1  \
# county
# Orleans         6649 N Blue Gum St   New Orleans    LA  70116  504-621-8927
# ...

# %% [markdown]
# Set the index to become the ‘county’ column.

# %%
df.rename(columns={"state" : "STATE"})
# Out:
#    first_name  last_name                    company_name  \
# 0       James       Butt               Benton, John B Jr
# 1   Josephine    Darakjy           Chanay, Jeffrey A Esq
# 2         Art     Venere             Chemel, James L Cpa
# 3       Lenna   Paprocki          Feltz Printing Service
# 4     Donette     Foller             Printing Dimensions
# ..        ...        ...                             ...
# 94     Elvera  Benimadho                 Tree Musketeers
# 95      Carma  Vanheusen    Springfield Div Oh Edison Co
# 96    Malinda    Hochard         Logan Memorial Hospital
# 97    Natalie       Fern            Kelly, Charles G Esq
# 98      Lisha    Centini  Industrial Paper Shredders Inc
#
#                   address          city       county STATE    zip  \
# 0      6649 N Blue Gum St   New Orleans      Orleans    LA  70116
# 1     4 B Blue Ridge Blvd      Brighton   Livingston    MI  48116
# 2    8 W Cerritos Ave #54    Bridgeport   Gloucester    NJ   8014
# ...

# %% [markdown]
# Rename columns using a mapping.

# %%
df.head(67)
# Out:
#    first_name last_name                   company_name               address  \
# 0       James      Butt              Benton, John B Jr    6649 N Blue Gum St
# 1   Josephine   Darakjy          Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 2         Art    Venere            Chemel, James L Cpa  8 W Cerritos Ave #54
# 3       Lenna  Paprocki         Feltz Printing Service           639 Main St
# 4     Donette    Foller            Printing Dimensions          34 Center St
# ..        ...       ...                            ...                   ...
# 62     Cecily   Hollack      Arthur A Oliver & Son Inc    59 N Groesbeck Hwy
# 63  Carmelina   Lindall  George Jessop Carter Jewelers         2664 Lewis Rd
# 64    Maurine  Yglesias           Schultz, Thomas C Md       59 Shady Ln #53
# 65      Tawna    Buvens          H H H Enterprises Inc  3305 Nabell Ave #679
# 66     Penney    Weight            Hawaiian King Hotel        18 Fountain St
#
# ...

# %% [markdown]
# preview the first 67 lines of the loaded data.

# %%
df.tail(45)
# Out:
#    first_name   last_name                    company_name  \
# 54       Karl   Klonowski                Rossi, Michael M
# 55    Tonette      Wenner            Northwest Publishing
# 56      Amber    Monarrez          Branford Wire & Mfg Co
# 57    Shenika     Seewald            East Coast Marketing
# 58      Delmy        Ahle            Wye Technologies Inc
# 59    Deeanna       Juhas              Healy, George W Iv
# 60   Blondell        Pugh                   Alpenlite Inc
# 61      Jamal   Vanausdal              Hubbard, Bruce Esq
# 62     Cecily     Hollack       Arthur A Oliver & Son Inc
# 63  Carmelina     Lindall   George Jessop Carter Jewelers
# 64    Maurine    Yglesias            Schultz, Thomas C Md
# 65      Tawna      Buvens           H H H Enterprises Inc
# 66     Penney      Weight             Hawaiian King Hotel
# 67       Elly     Morocco              Killion Industries
# 68      Ilene      Eroman         Robinson, William J Esq
# ...

# %% [markdown]
# if (n=45)means returns last 45rows.

# %%
len(df)
# Out:
# 99

# %% [markdown]
# Returns total number of rows.

# %%
df.dropna()
# Out:
#    first_name  last_name                    company_name  \
# 0       James       Butt               Benton, John B Jr
# 1   Josephine    Darakjy           Chanay, Jeffrey A Esq
# 2         Art     Venere             Chemel, James L Cpa
# 3       Lenna   Paprocki          Feltz Printing Service
# 4     Donette     Foller             Printing Dimensions
# ..        ...        ...                             ...
# 94     Elvera  Benimadho                 Tree Musketeers
# 95      Carma  Vanheusen    Springfield Div Oh Edison Co
# 96    Malinda    Hochard         Logan Memorial Hospital
# 97    Natalie       Fern            Kelly, Charles G Esq
# 98      Lisha    Centini  Industrial Paper Shredders Inc
#
#                   address          city       county state    zip  \
# 0      6649 N Blue Gum St   New Orleans      Orleans    LA  70116
# 1     4 B Blue Ridge Blvd      Brighton   Livingston    MI  48116
# 2    8 W Cerritos Ave #54    Bridgeport   Gloucester    NJ   8014
# ...

# %% [markdown]
# Dtaframe with NA entries dropped from it or None.

# %%
df.describe()
# Out:
#                 zip
# count     99.000000
# mean   50912.545455
# std    33051.252556
# min     2128.000000
# 25%    19066.500000
# 50%    48180.000000
# 75%    83304.000000
# max    99712.000000

# %% [markdown]
# Summary statistics of the Series or Dataframe provided.For numeric data, the result’s index will include count, mean, std, min, max as well as lower, 50 and upper percentiles. By default the lower percentile is 25 and the upper percentile is 75. The 50 percentile is the same as the median.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    99 non-null     object
#  1   last_name     99 non-null     object
#  2   company_name  99 non-null     object
#  3   address       99 non-null     object
#  4   city          99 non-null     object
#  5   county        99 non-null     object
#  6   state         99 non-null     object
#  7   zip           99 non-null     int64
#  8   phone1        99 non-null     object
#  9   phone         99 non-null     object
#  10  email         99 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 8.6+ KB

# %% [markdown]
# This method prints information about a dataframe including the index dtype and columns,non-null values and memory usage.

# %%
df.fillna
# Out:
# <bound method DataFrame.fillna of    first_name  last_name                    company_name  \
# 0       James       Butt               Benton, John B Jr
# 1   Josephine    Darakjy           Chanay, Jeffrey A Esq
# 2         Art     Venere             Chemel, James L Cpa
# 3       Lenna   Paprocki          Feltz Printing Service
# 4     Donette     Foller             Printing Dimensions
# ..        ...        ...                             ...
# 94     Elvera  Benimadho                 Tree Musketeers
# 95      Carma  Vanheusen    Springfield Div Oh Edison Co
# 96    Malinda    Hochard         Logan Memorial Hospital
# 97    Natalie       Fern            Kelly, Charles G Esq
# 98      Lisha    Centini  Industrial Paper Shredders Inc
#
#                   address          city       county state    zip  \
# 0      6649 N Blue Gum St   New Orleans      Orleans    LA  70116
# 1     4 B Blue Ridge Blvd      Brighton   Livingston    MI  48116
# ...

# %% [markdown]
# Fill NA/NAN values using the specified method.

# %%
df.to_csv()
# Out:
# ',first_name,last_name,company_name,address,city,county,state,zip,phone1,phone,email\n0,James,Butt,"Benton, John B Jr",6649 N Blue Gum St,New Orleans,Orleans,LA,70116,504-621-8927,504-845-1427,jbutt@gmail.com\n1,Josephine,Darakjy,"Chanay, Jeffrey A Esq",4 B Blue Ridge Blvd,Brighton,Livingston,MI,48116,810-292-9388,810-374-9840,josephine_darakjy@darakjy.org\n2,Art,Venere,"Chemel, James L Cpa",8 W Cerritos Ave #54,Bridgeport,Gloucester,NJ,8014,856-636-8749,856-264-4130,art@venere.org\n3,Lenna,Paprocki,Feltz Printing Service,639 Main St,Anchorage,Anchorage,AK,99501,907-385-4412,907-921-2010,lpaprocki@hotmail.com\n4,Donette,Foller,Printing Dimensions,34 Center St,Hamilton,Butler,OH,45011,513-570-1893,513-549-4561,donette.foller@cox.net\n5,Simona,Morasca,"Chapman, Ross E Esq",3 Mcauley Dr,Ashland,Ashland,OH,44805,419-503-2484,419-800-6759,simona@morasca.com\n6,Mitsue,Tollner,Morlong Associates,7 Eads St,Chicago,Cook,IL,60632,773-573-6914,773-924-8565,mitsue_tollner@yahoo.com\n7,Leota,Dill
# ...

# %% [markdown]
# If path_or_buf is None, returns the resulting csv format as a string. Otherwise returns None.

# %%
df.max()
# Out:
# first_name                       Yuki
# last_name                    Yglesias
# company_name     Wye Technologies Inc
# address         99385 Charity St #840
# city                         Westbury
# county                      Winnebago
# state                              WY
# zip                             99712
# phone1                   973-927-3447
# phone                    973-847-9611
# email            yuki_whobrey@aol.com
# dtype: object

# %% [markdown]
# Return the maximum over the requested axis.

# %%
df.min()
# Out:
# first_name                          Abel
# last_name                       Abdallah
# company_name         A K Construction Co
# address                    1 Central Ave
# city                             Abilene
# county                               Ada
# state                                 AK
# zip                                 2128
# phone1                      201-709-6245
# phone                       201-387-9093
# email           ahoneywell@honeywell.com
# dtype: object

# %% [markdown]
# Return the minimum of the values over the requested axis.

# %%
df.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# zip    33051.252556
# dtype: float64

# %% [markdown]
# Return sample standard deviation over requested axis.
